# %% [markdown]
# # Machine Learning: A Quantitative Approach

# %% [markdown]
# + The general notion here is that LASSO (Least Absolute Shrinkage Selection Operator) regularization forces certain coefficients to be set to zero, which effectively forces choosing a simpler model that does not include those coefficients, thus effectively suppresses overfitting.

# %%
# %matplotlib inline

# %%
import sys, csv
import time

import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from time import time
import matplotlib.style as style
from collections import Counter
import seaborn as sns

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures

# %%
style.use('seaborn-poster') # sets the size of the charts
style.use('ggplot') # set the theme for matplotlib

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ### Dataset

# %%
vehicles_df = pd.read_csv("datasets/vehicles.csv", low_memory = False)

# %%
vehicles_displ_mpg_all = vehicles_df[['displ', 'UHighway']]

# %%
vehicles_displ_mpg = vehicles_displ_mpg_all[vehicles_displ_mpg_all.displ > 0]

# %% [markdown]
# ### Split / Train Test

# %%
half = int(len(vehicles_displ_mpg) / 2)

# %%
first_half = vehicles_displ_mpg[:half]
second_half = vehicles_displ_mpg[half:]

# %%
first_half_sorted = first_half.sort_values(by=['displ', 'UHighway'])
first_half_grouped_by_median = pd.DataFrame(
    {'train_median' : first_half_sorted.groupby('displ')['UHighway'].median()}).reset_index()

# %%
first_half_x = first_half_grouped_by_median['displ'].values.reshape(-1,1)

# %%
print(type(first_half_x))
# Out:
# <class 'numpy.ndarray'>

# %%
first_half_y = first_half_grouped_by_median['train_median'].values.reshape(-1,1)

# %%
second_half_sorted = second_half.sort_values(by=['displ', 'UHighway'])
second_half_grouped_by_median = pd.DataFrame(
    {'test_median' : second_half_sorted.groupby('displ')['UHighway'].median()}).reset_index()

# %%
second_half_x = second_half_grouped_by_median['displ'].values.reshape(-1, 1)
second_half_y = second_half_grouped_by_median['test_median'].values.reshape(-1,1)

# %%
def lasso_reg(alpha = 0.1):
    colors = ['green', 'blue', 'red', 'purple']
    lw = 1

    for count, degree in enumerate([1, 2, 4, 8]):
        model = make_pipeline(PolynomialFeatures(degree), Lasso(alpha=alpha))
        model.fit(first_half_x, first_half_y)
        second_half_y_pred = model.predict(second_half_x)

        plt.plot(second_half_x, second_half_y_pred, color=colors[count], linewidth=lw,
                label="degree %d" % degree)
        print("degree %d" % degree)
        mse = mean_squared_error(second_half_y, second_half_y_pred)
        rmse = np.sqrt(mse)
        print("\tModel parameters: ", model.get_params(deep=False))
        print("\tMean squared error: %.2f" % mse,"\tRoot mean squared error: %.2f" % rmse, \
            '\tR-squared score: %.2f' % r2_score(second_half_y, second_half_y_pred))

    # Plot outputs
    plt.scatter(second_half_x, second_half_y,  color='gold')
    #plt.plot(second_half_x, second_half_y_pred, color='blue', linewidth=3)
    plt.title ("alpha= %f" % alpha, fontsize=15)
    plt.xlabel ("Engine displacement (liter)", fontsize = 15)
    plt.ylabel ("Fuel economy (MPG)", fontsize = 15)
    plt.legend(loc='upper right', fontsize = 15)
    plt.show()

# %%
lasso_reg(0.1)
# Out:
# degree 1
# 	Model parameters:  {'memory': None, 'steps': [('polynomialfeatures', PolynomialFeatures(degree=1, include_bias=True, interaction_only=False)), ('lasso', Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False))]}
# 	Mean squared error: 31.17 	Root mean squared error: 5.58 	R-squared score: 0.65
# degree 2
# 	Model parameters:  {'memory': None, 'steps': [('polynomialfeatures', PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)), ('lasso', Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False))]}
# 	Mean squared error: 22.37 	Root mean squared error: 4.73 	R-squared score: 0.75
# degree 4
# 	Model parameters:  {'memory': None, 'steps': [('polynomialfeatures', PolynomialFeatures(degree=4, include_bias=True, interaction_only=False)), ('lasso', Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False))]}
# 	Mean squared error: 22.71 	Root mean squared error: 4.77 	R-squared score: 0.74
# degree 8
# 	Model parameters:  {'memory': None, 'steps': [('polynomialfeatures', PolynomialFeatures(degree=8, include_bias=True, interaction_only=False)), ('lasso', Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False))]}
# 	Mean squared error: 22.76 	Root mean squared error: 4.77 	R-squared score: 0.74
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
lasso_reg(1)
# Out:
# degree 1
# 	Model parameters:  {'memory': None, 'steps': [('polynomialfeatures', PolynomialFeatures(degree=1, include_bias=True, interaction_only=False)), ('lasso', Lasso(alpha=1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False))]}
# 	Mean squared error: 32.18 	Root mean squared error: 5.67 	R-squared score: 0.64
# degree 2
# 	Model parameters:  {'memory': None, 'steps': [('polynomialfeatures', PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)), ('lasso', Lasso(alpha=1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False))]}
# 	Mean squared error: 26.93 	Root mean squared error: 5.19 	R-squared score: 0.70
# degree 4
# 	Model parameters:  {'memory': None, 'steps': [('polynomialfeatures', PolynomialFeatures(degree=4, include_bias=True, interaction_only=False)), ('lasso', Lasso(alpha=1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False))]}
# 	Mean squared error: 28.04 	Root mean squared error: 5.30 	R-squared score: 0.68
# degree 8
# 	Model parameters:  {'memory': None, 'steps': [('polynomialfeatures', PolynomialFeatures(degree=8, include_bias=True, interaction_only=False)), ('lasso', Lasso(alpha=1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False))]}
# 	Mean squared error: 26.16 	Root mean squared error: 5.11 	R-squared score: 0.70
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
